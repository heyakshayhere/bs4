# %% [markdown]
# **url:**
#
# https://sputnikvaccine.com/newsroom/?PAGEN_1=5

# %%
import pandas as pd,requests,bs4,re,time
from datetime import datetime
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %autosave 1
# Out:
# Autosaving every 1 seconds

# %%
SITE_NAME='Sputnikvaccine'

DOMAIN = "https://sputnikvaccine.com"

SITE_LINK="https://sputnikvaccine.com/newsroom"

# %%
def remove_esc_chars(text):
    return text.replace("\n", " ").replace("\t", " ").replace("\r", " ")

# %%
def parse_webpage_bs(search_url):
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:90.0) Gecko/20100101 Firefox/90.0"}
    try:
        site_request = requests.get(search_url, headers=headers, timeout=10)
    except requests.exceptions.RequestException as e:
        print(e)
        site_request = None
    if site_request != None and site_request.status_code==200:
        site_soup = bs4.BeautifulSoup(site_request.content, "lxml")
    else:
        site_soup = None
    return site_soup

# %%
def get_news_data(element):
    titles,published_dates,thumbnails,hrefs,authors,articles = [],[],[],[],[],[]
    #titles
    headlines = element.find('a')
    for t in headlines:
        if t != None:
            title = remove_esc_chars(t.text)
            titles.append(title.strip())
        else:
            titles.append("")

    #dates
    dates = element.find_all('span',{'class' :'newsroom-template__item-date'})
    for d in dates:
        if d != None:
            published_date = d.text.replace(",","")
            published_dates.append(published_date.strip())
        else:
            published_dates.append("")


    #thumbnails
    T = 'https://sputnikvaccine.com/local/templates/sputnik/img/logo_inner_new.svg'
    thumbnails.append(T.strip())

    site_all_hrefs = []
    #hrefs and authors
    hrefs_container = element.find_all('a')
    for href in hrefs_container:
        if href != None:
            href = href['href']
            hrefs.append(href.strip())
            site_all_hrefs.append(href.strip())
            authors.append(SITE_NAME.strip())
        else:
            hrefs.append("")
            authors.append(SITE_NAME.strip())

    #extracting text 
    for number,link in enumerate (site_all_hrefs):
        if re.findall(".pdf",link):
            articles.append("")
        else:
            try:
                soup = parse_webpage_bs(link)
                art_containers = soup.findAll('p')
                if len(art_containers)>1:
                    for art in art_containers:
                        article = remove_esc_chars(art.text)
                        articles.append(article.strip())
                else:
                    time.sleep(6)
                    for art in art_containers:
                        article = remove_esc_chars(art.text)
                        articles.append(article.strip())
            except:
                articles.append("")
    return titles,published_dates,hrefs,authors,thumbnails,articles

# %%
article_list = []
pagination = 1
last_page = 3 #10
while True:
    url = f"https://sputnikvaccine.com/newsroom/?PAGEN_1={pagination}"
    soup = parse_webpage_bs(url)
    if soup != None:
        elements = soup.find_all('div',{'class' :'newsroom-template__item'})
        for element in elements: 
            titles,published_dates,links,authors,thumbnails,texts = get_news_data(element)
            datas = [titles,published_dates,links,authors,thumbnails,texts]
            
            for x in range(len(datas[0])):
                try:
                    published_date = datas[datas.index(published_dates)][x]
                    title = datas[datas.index(titles)][x]
                    text = datas[datas.index(texts)][x]
                    link = datas[datas.index(links)][x]
                    thumbnail = datas[datas.index(thumbnails)][x]
                    author = datas[datas.index(authors)][x]
                    article = (published_date,title,text,link,thumbnail,author)
                    article_list.append(article)
                    print(published_date,title)
                except:
                    pass
                
    pagination += 1
    
    print(str(last_page-pagination+1) + " pages remaining..",end="\r")
    
    if pagination > last_page:
        break
# Out:
# 06.02.2022 Russia says India approves one-shot Sputnik Light COVID vaccine
# 06.02.2022 Sputnik Light vaccine gets EUA in India
# 20.01.2022 COVID-19: Sputnik V shows strong protection against Omicron compared to Pfizer vaccine, says Italy-Russia joint study
# 20.01.2022 Sputnik V better than Comirnaty against Omicron, study says
# 25.12.2021 Laos becomes 20th country to authorise one-shot Sputnik Light vaccine
# 25.11.2021 Sputnik V shows 80 long-term efficacy against COVID in San Marino from 6th through 8th month after administering the second dose
# 25.11.2021 RDIF: Sputnik most efficient jab in study in Hungary
# 25.11.2021 Russia says Sputnik gives longer protection than Western coronavirus jabs
# 25.11.2021 Russia says Sputnik gives longer protection than Western jabs
# 03.11.2021 Sputnik Light produces strong level of antibodies against COVID-19 - early-stage trial
# 01.11.2021 Argentinian study proves high efficacy of Sputnik V in protecting people over 60: RDIF
# 26.10.2021 S.Korea's GL Rapha certified to produce Sputnik COVID-19 vaccines
# 13.10.2021 Russia says Sputnik Light is 70% effective against Delta variant
# 06.10.2021 UAE authorises Sputnik Light COVID-19 vaccine -Russia's RDIF
# 27.09.2021 Small study shows antibody growth from AstraZeneca, Sputnik Light COVID-19 vaccine mix
# 25.09.2021 Egypt approves Russian single-component Sputnik Light vaccine against COVID-19: RDIF
# 13.09.2021 First component of Sputnik V shows 78.6-83.7 pc general efficacy against COVID-19 in elderly subjects: Study in Argentina
# 06.09.2021 Armenia approves one-dose Sputnik Light COVID-19 vaccine for use - RDIF
# 26.08.2021 Strength of Antibodies From Sputnik V COVID Vaccine Grows With Time - Argentine Ministry
# 25.08.2021 Indonesia becomes the 70th nation to authorize Sputnik V
# 23.08.2021 Philippines approves emergency use of Russia's Sputnik Light vaccine
# 20.08.2021 Small-scale study on mixing Sputnik V, AstraZeneca shows positive result - RDIF
# 18.08.2021 Russia says Sputnik Light 93.5% effective in Paraguay
# 12.08.2021 First batches of the Sputnik V vaccine produced in Uzbekistan by Jurabek Laboratories
# 11.08.2021 Sputnik V jab 83 per cent effective against Delta variant, says Russian health ministry
# 05.08.2021 Argentina handles Sputnik V delay by giving second jabs of other vaccines
# 30.07.2021 Mixing Russia's Sputnik V, AstraZeneca shots proves safe in small trial -RDIF
# 21.07.2021 Vietnam produces first batch of Russian COVID-19 vaccine
# 0 pages remaining..

# %%
temp_df = pd.DataFrame(article_list,columns=['date','title','article','url','thumbnail','author'])
temp_df
# Out:
#           date                                              title  \
# 0   06.02.2022  Russia says India approves one-shot Sputnik Li...
# 1   06.02.2022            Sputnik Light vaccine gets EUA in India
# 2   20.01.2022  COVID-19: Sputnik V shows strong protection ag...
# 3   20.01.2022  Sputnik V better than Comirnaty against Omicro...
# 4   25.12.2021  Laos becomes 20th country to authorise one-sho...
# 5   25.11.2021  Sputnik V shows 80 long-term efficacy against ...
# 6   25.11.2021  RDIF: Sputnik most efficient jab in study in H...
# 7   25.11.2021  Russia says Sputnik gives longer protection th...
# 8   25.11.2021  Russia says Sputnik gives longer protection th...
# 9   03.11.2021  Sputnik Light produces strong level of antibod...
# 10  01.11.2021  Argentinian study proves high efficacy of Sput...
# 11  26.10.2021  S.Korea's GL Rapha certified to produce Sputni...
# 12  13.10.2021  Russia says Sputnik Light is 70% effective aga...
# 13  06.10.2021  UAE authorises Sputnik Light COVID-19 vaccine ...
# 14  27.09.2021  Small study shows antibody growth from AstraZe...
# 15  25.09.2021  Egypt approves Russian single-component Sputni...
# 16  13.09.2021  First component of Sputnik V shows 78.6-83.7 p...
# 17  06.09.2021  Armenia approves one-dose Sputnik Light COVID-...
# 18  26.08.2021  Strength of Antibodies From Sputnik V COVID Va...
# 19  25.08.2021  Indonesia becomes the 70th nation to authorize...
# 20  23.08.2021  Philippines approves emergency use of Russia's...
# 21  20.08.2021  Small-scale study on mixing Sputnik V, AstraZe...
# 22  18.08.2021  Russia says Sputnik Light 93.5% effective in P...
# 23  12.08.2021  First batches of the Sputnik V vaccine produce...
# 24  11.08.2021  Sputnik V jab 83 per cent effective against De...
# 25  05.08.2021  Argentina handles Sputnik V delay by giving se...
# 26  30.07.2021  Mixing Russia's Sputnik V, AstraZeneca shots p...
# 27  21.07.2021  Vietnam produces first batch of Russian COVID-...
#
#                                               article  \
# 0   A view shows vials with the one-dose Sputnik L...
# 1   We have updated our terms and conditions and p...
# 2             ANI |  Updated: Jan 20, 2022 17:37  IST
# 3
# 4
# 5   (Eds: Disclaimer: The following press release ...
# 6
# 7   MOSCOW (AFP) - The backers of Sputnik V on Wed...
# 8
# 9   A view shows vials with the one-dose Sputnik L...
# 10            ANI |  Updated: Nov 01, 2021 13:45  IST
# 11  An employee holds a vial containing Sputnik va...
# 12  MOSCOW, Oct 13 (Reuters) - Russia's Sputnik Li...
# 13  A view shows boxes containing vials with the o...
# 14  A woman receives a dose of Sputnik V (Gam-COVI...
# 15                                                 BY
# 16            ANI |  Updated: Sep 13, 2021 19:21  IST
# 17                           Discover Thomson Reuters
# 18  Buenos Aires, Aug 26 (UNI/Sputnik) Argentine s...
# 19                       ANI25 Aug 2021, 21:18 GMT+10
# 20  A view shows boxes containing vials with the o...
# 21                           Discover Thomson Reuters
# 22                                         By Reuters
# 23  The Russian Direct Investment Fund (RDIF, Russ...
# 24            ANI |  Updated: Aug 11, 2021 16:36  IST
# 25  A shipment of doses of the Sputnik V (Gam-COVI...
# 26
# 27  A medical specialist holds a vial of Sputnik V...
#
#                                                   url  \
# 0   https://www.reuters.com/world/india/russia-say...
# 1   https://health.economictimes.indiatimes.com/ne...
# 2   https://www.aninews.in/news/national/general-n...
# 3   https://www.thepharmaletter.com/article/sputni...
# 4   https://asianews.network/laos-becomes-20th-cou...
# 5   https://www.theweek.in/wire-updates/business/2...
# 6   https://www.teletrader.com/rdshf-sputnik-most-...
# 7   https://www.straitstimes.com/world/europe/russ...
# 8   https://www.philstar.com/lifestyle/health-and-...
# 9   https://www.reuters.com/business/healthcare-ph...
# 10  https://www.aninews.in/news/world/us/argentini...
# 11  https://www.reuters.com/business/healthcare-ph...
# 12  https://www.reuters.com/business/healthcare-ph...
# 13  https://www.reuters.com/world/middle-east/uae-...
# 14  https://www.reuters.com/business/healthcare-ph...
# 15  https://www.egypttoday.com/Article/1/108162/Eg...
# 16  https://www.aninews.in/news/world/europe/first...
# 17  https://www.reuters.com/article/health-coronav...
# 18  http://www.uniindia.com/news/world/strength-of...
# 19  https://www.parisguardian.com/news/270872579/i...
# 20  https://www.reuters.com/world/asia-pacific/phi...
# 21  https://www.reuters.com/article/healthcoronavi...
# 22  https://www.dailymail.co.uk/wires/reuters/arti...
# 23  https://en.trend.az/casia/uzbekistan/3463689.html
# 24  https://www.aninews.in/news/world/others/sputn...
# 25  https://www.reuters.com/world/americas/argenti...
# 26  https://www.reuters.com/business/healthcare-ph...
# 27  https://www.reuters.com/world/asia-pacific/vie...
#
#                                             thumbnail          author
# 0   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 1   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 2   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 3   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 4   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 5   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 6   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 7   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 8   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 9   https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 10  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 11  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 12  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 13  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 14  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 15  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 16  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 17  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 18  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 19  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 20  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 21  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 22  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 23  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 24  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 25  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 26  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine
# 27  https://sputnikvaccine.com/local/templates/spu...  Sputnikvaccine

# %%
for x in range(len(temp_df)):    
    print(temp_df.iloc[x]['article'])
    print()
# Out:
# A view shows vials with the one-dose Sputnik Light vaccine against the coronavirus disease (COVID-19) in a vaccination centre at a city market in Moscow, Russia, June 30, 2021. REUTERS/Tatyana Makeyeva
#
# We have updated our terms and conditions and privacy policy  Click "Continue" to accept and continue with ET HealthWorld
#
# ANI |  Updated: Jan 20, 2022 17:37  IST
#
#
#
#
#
# (Eds: Disclaimer: The following press release comes to you under an arrangement with PRNewswire. PTI takes no editorial responsibility for the same.) MOSCOW, Nov. 24, 2021 /PRNewswire/ -- The Russian Direct Investment Fund (RDIF, Russia's sovereign wealth fund) announces the real-world data of the Ministry of Health of the Republic of San Marino on the Russian Sputnik V vaccine demonstrating it is 80% effective against coronavirus infection from 6th to 8th months after administering the second dose.Efficacy of Sputnik V on 6-8 months is much higher than officially published efficacy of mRNA vaccines. Sputnik team believes that adenoviral vaccines provide for longer efficacy than mRNA vaccines due to longer antibody and T-cell response.The data is based on the number of COVID infections in San Marino in November 2021. Efficacy was calculated based on data obtained from over 18,600 individuals fully vaccinated with Sputnik V not less than 5 months before November.The hospitalization rate with COVID infection following vaccination with Sputnik V in San Marino was only 0.75 per 1,000 people during the entire mass vaccination in the country from February to November 2021. This rate is more than 2 times lower than that of any other vaccine used in the country.Over 70% of the adult population of San Marino have been vaccinated with Sputnik V.An article published in EClinicalMedicine (an open access clinical journal published by The Lancet, one of the world's most respected medical journals) in July demonstrated that the Russian vaccine has a high safety profile in San Marino. In particular, Sputnik V shows high tolerability profile in ≥60 age group with nearly all reported adverse events following immunization being mild or moderate and lasting less than 2 days.Sputnik V pioneered the heterogeneous boosting approach (a "vaccine cocktail" using human adenovirus serotype 26 as the first component and human adenovirus serotype 5 as the second component). This approach was proven to be successful in creating a longer and more durable immunity against coronavirus. Sputnik team offered its booster shot (one-shot Sputnik Light vaccine) to other vaccines to lengthen and strengthen their immune response and took the lead in initiating partnerships around the world to conduct joint studies on the combination of Sputnik Light with vaccines of other producers.  PWRPWR
#
#
#
# MOSCOW (AFP) - The backers of Sputnik V on Wednesday (Nov 24) said the Russian vaccine provides longer immunity against coronavirus than Western jabs using messenger RNA (mRNA) technology.
#
#
#
# A view shows vials with the one-dose Sputnik Light vaccine against the coronavirus disease (COVID-19) in a vaccination centre at a city market in Moscow, Russia, June 30, 2021. REUTERS/Tatyana Makeyeva
#
# ANI |  Updated: Nov 01, 2021 13:45  IST
#
# An employee holds a vial containing Sputnik vaccine at a factory of Hankook Korus Pharm, in Chuncheon, South Korea September 10, 2021. Picture taken September 10, 2021.  REUTERS/Heo Ran
#
# MOSCOW, Oct 13 (Reuters) - Russia's Sputnik Light vaccine shows 70% effectiveness against the Delta variant of COVID-19 three months after injection and the one-shot product is likely to become the country's main vaccine, Russia's sovereign wealth fund said on Wednesday.
#
# A view shows boxes containing vials with the one-dose Sputnik Light vaccine against the coronavirus disease (COVID-19) in a vaccination centre at a city market in Moscow, Russia, June 30, 2021. REUTERS/Tatyana Makeyeva
#
# A woman receives a dose of Sputnik V (Gam-COVID-Vac) vaccine against the coronavirus disease (COVID-19) at a vaccination centre in a shopping mall in Saint Petersburg, Russia February 24, 2021. REUTERS/Anton Vaganov/File Photo
#
# BY
#
# ANI |  Updated: Sep 13, 2021 19:21  IST
#
# Discover Thomson Reuters
#
# Buenos Aires, Aug 26 (UNI/Sputnik) Argentine scientists have found that the neutralizing power of antibodies produced after inoculation with Russia's Sputnik V vaccine only increases with time, the country's Ministry of Science, Technology and Innovation said.  The researchers analyzed the number of antibodies and their ability to neutralize coronavirus and its variants on 1,800 blood samples from people who had recovered from COVID-19 and those who had never been infected with it. Samples were taken, including 21, 42, 120 and 180 days after vaccination with the Russian medicine.  "Although there is concern worldwide that the number of antibodies generated after vaccination is decreasing with time, now, for the first time, an Argentine study shows an increase in their neutralizing power against coronavirus depending on when the vaccine was received," the ministry said.  "The Argentine study confirms the increasing efficacy of neutralizing antibodies 6 months after the use of Sputnik V," it said.  UNI/SPUTNIK ASN
#
# ANI25 Aug 2021, 21:18 GMT+10
#
# A view shows boxes containing vials with the one-dose Sputnik Light vaccine against the coronavirus disease (COVID-19) in a vaccination centre at a city market in Moscow, Russia, June 30, 2021. REUTERS/Tatyana Makeyeva
#
# Discover Thomson Reuters
#
# By Reuters
#
# The Russian Direct Investment Fund (RDIF, Russia’s sovereign wealth fund), and one of the leading pharmaceutical companies of Uzbekistan, Jurabek Laboratories, today announced the first batches of the Russian Sputnik vaccine against coronavirus have been produced at company’s facilities, Trend reports citing Russian media.
#
# ANI |  Updated: Aug 11, 2021 16:36  IST
#
# A shipment of doses of the Sputnik V (Gam-COVID-Vac) vaccine against the coronavirus disease (COVID-19) is seen after arriving at Ezeiza International Airport, in Buenos Aires, Argentina, January 28, 2021. REUTERS/Agustin Marcarian
#
#
#
# A medical specialist holds a vial of Sputnik V vaccine against the coronavirus in a department store in Moscow, Russia, January 18, 2021 REUTERS/Shamil Zhumatov/File Photo

# %%
#to csv
temp_df.to_csv('Sputnikvaccine news.csv')

#to json
temp_df.to_json('Sputnikvaccine news.json')
