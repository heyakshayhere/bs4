# %%
import pandas as pd,requests,bs4
from datetime import datetime
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %%
def get_article_body(url):
    site_soup = parse_webpage_bs(url)
    if site_soup!=None:  
        try:
            content = []
            paragraphs = site_soup.findAll('div',{'class' :'module_body'})
            for para in paragraphs:
                text = remove_esc_chars(para.get_text().strip())
                content.append(text)
                text = " ".join(content)
        except:
            text = ""
        return text
    else:
        return ""

# %%
def parse_webpage_bs(search_url):
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:90.0) Gecko/20100101 Firefox/90.0"}
    try:
        site_request = requests.get(search_url, headers=headers, timeout=10)
    except requests.exceptions.RequestException as e:
        print(e)
        site_request = None
    if site_request != None and site_request.status_code==200:
        site_soup = bs4.BeautifulSoup(site_request.content, "lxml")
    else:
        site_soup = None
    return site_soup

# %%
SITE_NAME='Astellas'

DOMAIN = "https://www.astellas.com"

SITE_LINK="https://www.astellas.com/en/news"

# %%
def get_news_data(element):
    try:
        link = DOMAIN + element['href']
#         published_date = element.find(IDENS.published_date.get('tag')).text.strip()
#         title = element.find(IDENS.title.get('tag')).get_text().strip()
#         author = SITE_NAME
#         thumbnail = ""
#         text = self.get_article_body(link)
        return link#, title, published_date , thumbnail, text, author
    except:
        return None#, None, None, None, None, None

# %%
def get_news_data(element):
    link = element['href']
    return link

# %%
def remove_esc_chars(text):
    return text.replace("\n", " ").replace("\t", " ").replace("\r", " ")

# %%
article_list = []
titles,published_dates,thumbnails,hrefs,authors = [],[],[],[],[]
pagination = 0
last_page = 3 #250
while True:
    url = f"https://www.astellas.com/en/news?tab=latest&page={pagination}"
    soup = parse_webpage_bs(url)
    if soup != None:
        elements = soup.find_all('div',{'id' :'latest'})
        for element in elements: 
            #titles
            headlines = element.find_all('div',{'class' :'views-field-field-title'})
            for t in headlines:
                if t != None:
                    title = remove_esc_chars(t.text)
                    titles.append(title.strip())
                else:
                    titles.append("")
                    
            #dates
            dates = element.find_all('div',{'class' :'views-field-field-release-date'})
            for d in dates:
                if d != None:
                    published_date = d.text
                    published_dates.append(published_date.strip())
                else:
                    published_dates.append("")
                    
                    
            #thumbnails
            thumbnails_container = element.find_all('div',{'class' :'views-field-field-country-icon'})
            for thumb in thumbnails_container:
                if thumb != None:
                    thumbnail = thumb.find('img')
                    T = DOMAIN + thumbnail['src']
                    thumbnails.append(T.strip())
                else:
                    thumbnails.append("")
            
            #hrefs and authors
            hrefs_container = element.find_all('div',{'class' :'views-row'})
            for href in hrefs_container:
                if href != None:
                    href = DOMAIN + href.find('a')['href']
                    hrefs.append(href.strip())
                    authors.append(SITE_NAME.strip())
                else:
                    hrefs.append("")
                    authors.append(SITE_NAME.strip())
            
    pagination += 1
    
    print(str(last_page-pagination+1) + " pages remaining..",end="\r")
    
    if pagination > last_page:
        break
# Out:
# 0 pages remaining..

# %%
import re 
articles  = []

for number,link in enumerate (hrefs):
    if re.findall(".pdf",link):
        articles.append("")
    else:
        soup = parse_webpage_bs(link)
        art_containers = soup.findAll('p')
        for art in art_containers:
            article = remove_esc_chars(art.text)
            articles.append(article)
        
    print(f"scrapping done for url {len(hrefs) - number-1}..",end="\r")
# Out:
# scrapping done for url 0...

# %%
#zippling the list so that it'll form the tuple
zipped = list(zip(published_dates,titles,articles,thumbnails,hrefs,authors))
temp_df = pd.DataFrame(zipped,columns=['date','title','article','thumbnail','url','author'])
temp_df
# Out:
#             date                                              title  \
# 0   May 20, 2022  Astellas Confirms Unfavorable District Court D...
# 1   May 19, 2022  Astellas Analysis Shows No Evidence of Increas...
# 2   May 16, 2022  Astellas to Present New Research Further Suppo...
# 3   May 13, 2022  Astellas Highlights Data on Advanced and Rare ...
# 4   May 12, 2022  Notice Regarding Continuation of the Performan...
# 5   May 12, 2022  Notice Regarding Continuation of the Performan...
